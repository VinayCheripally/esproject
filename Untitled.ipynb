# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("water_potability.csv")

# %%
df = df[(df["ph"] > 4.0) & (df["ph"] < 5.5)].sort_values('ph')
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2890  4.004248  210.486009  32821.850091     6.868438         NaN
# 2977  4.016590  255.616569  28612.266107     7.340595  290.690661
# 622   4.029053  203.386857  42327.168016     8.550483  279.675256
# 2481  4.031610  145.483239  15105.373098     8.180813  333.710870
# 3087  4.032061  200.067973  14720.544829     6.482679         NaN
# ...        ...         ...           ...          ...         ...
# 2349  5.495976  150.534519  18333.632664     7.471728  416.888527
# 612   5.497580  204.682870  29493.422967     7.604130  323.608786
# 2356  5.498515  180.825114  21542.830032     6.707095  352.250711
# 1042  5.499489  230.308775  13902.968646     9.619575  352.084333
# 2537  5.499788  150.076090  43195.473668     6.570596  322.516582
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2890    354.439531       14.504058        58.514082   4.445946           0
# 2977    442.385118        9.305733        71.342132   4.417134           0
# 622     503.732428       13.758836        46.384064   4.179656           0
# 2481    342.979013       13.806406        85.679053   4.037939           0
# 3087    519.213370       16.600777        77.293940   4.814235           0
# ...            ...             ...              ...        ...         ...
# 2349    300.358972       12.300193        55.706781   4.901038           1
# 612     476.844459       16.672415        83.413838   5.060115           0
# 2356    419.512958       13.183432        68.904370   3.074815           1
# 1042    442.167006       14.740787              NaN   5.846827           0
# 2537    287.286057       11.230408        71.821281   3.668220           0
#
# [336 rows x 10 columns]

# %%
plt.figure(figsize=(20, 4))

x_ = [i for i in range(1, 337)]
y = df['ph']

plt.scatter(x_, y)

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot of pH')

plt.show()
